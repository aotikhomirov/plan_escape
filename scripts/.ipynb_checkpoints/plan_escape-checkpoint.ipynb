# %%
import pandas as pd
import numpy as np
import re
import datetime

data = pd.read_excel('C:\Users\Valery\Desktop\plan_escape\data\zyablikovo_110916.xlsx')
dt = datetime.date(2016, 9, 11)

def first_number(x):
    x = re.sub(' +', '', x)
    if x == 'NULL':
        return -1
    else:
        return int(re.findall('^\d+', x)[0])

def text_string(x):
    x = re.sub(' +', '', x)
    if x == 'NULL':
        return 'NULL'
    else:
        return re.findall('^\d+(\D+)', x)[0] 

def phone_num(x):
    phone_list = re.findall('\d.\d{3}.\d{3}.\d{2}.\d{2}',x)
    phone_list = [re.sub('\D','',x) for x in phone_list]
    if len(phone_list) == 0:
        return [-1,-1]
    else:
        phone_list = [int(x) for x in phone_list]
    if len(phone_list) == 1:
        phone_list.append(-1)
    return phone_list

def time_posting(x):
    hour = int(re.findall(', (\d+):\d+',x)[0])
    minute = int(re.findall(', \d+:(\d+)',x)[0])
    s = re.split(',', x)[0]
    if s == u'вчера':
        dt_tmp = dt + datetime.timedelta(-1)
        day = dt_tmp.day
        month = dt_tmp.month
    elif s == u'сегодня': 
        day = dt.day
        month = dt.month
    else:
        s = re.sub(u'янв', '01', s.lower())
        s = re.sub(u'фев', '02', s.lower())
        s = re.sub(u'мар', '03', s.lower())
        s = re.sub(u'апр', '04', s.lower())
        s = re.sub(u'май', '05', s.lower())
        s = re.sub(u'июн', '06', s.lower())
        s = re.sub(u'июл', '07', s.lower())
        s = re.sub(u'авг', '08', s.lower())
        s = re.sub(u'сен', '09', s.lower())
        s = re.sub(u'окт', '10', s.lower())
        s = re.sub(u'ноя', '11', s.lower())
        s = re.sub(u'дек', '12', s.lower())
        day = int(re.findall('(\d+) \d+', s)[0])
        month = int(re.findall('\d+ (\d+)', s)[0])
    year = datetime.date.today().year
    return datetime.datetime(year,month,day,hour,minute)

cnt_rooms = data.cnt_rooms.apply(lambda x: int(re.findall('^\d',x)[0]))
flat_ids = data.url.apply(lambda x: int(re.findall('/(\d+)/',x)[0]))
data.dt_metro.fillna('NULL',inplace=True)
dt_metro_int = data.dt_metro.apply(first_number)
dt_metro_type =  data.dt_metro.apply(text_string)
popularity_all = data.popularity.apply(lambda x: int(re.findall(u'всего (\d+)',x)[0]))
popularity_today = data.popularity.apply(lambda x: int(re.findall(u'сегодня (\d+)',x)[0]))
floor_cur = data.floor.apply(lambda x: int(re.split('/',x)[0]))
floor_all = data.floor.apply(lambda x: int(re.split('/',x)[1]))
living_area = data.living_area.apply(lambda x: float(re.sub(u'\u2013','-1',re.sub(',','.',re.sub(u'м2','',x)))))
kitchen_area = data.kitchen_area.apply(lambda x: float(re.sub(u'\u2013','-1',re.sub(',','.',re.sub(u'м2','',x)))))
for f in ['avg_price_m2_in_house',
          'avg_rental_rate',
          'district_population',
          'avg_age',
          'avg_price_m2_in_district']:
    data[f].fillna('0',inplace=True)
avg_price_m2_in_house = data.avg_price_m2_in_house.apply(lambda x: re.sub('\D','',x))
avg_rental_rate = data.avg_rental_rate.apply(lambda x: re.sub('\D','',x))
district_population = data.district_population.apply(lambda x: re.sub('\D','',x))
avg_age = data.avg_age.apply(lambda x: re.sub('\D','',x))
avg_price_m2_in_district = data.avg_price_m2_in_district.apply(lambda x: re.sub('\D','',x))
phone_first = [x[0] for x in data.message.apply(phone_num)]
phone_second = [x[1] for x in data.message.apply(phone_num)]

data_clean = pd.DataFrame(data=zip(flat_ids,
                          cnt_rooms,
                          data.total_area,
                          kitchen_area,
                          living_area,
                          floor_cur,
                          floor_all,
                          data.price_all,
                          np.round((data.price_all/data.total_area).values),
                          avg_price_m2_in_house,
                          avg_price_m2_in_district,
                          avg_rental_rate,
                          popularity_today,
                          popularity_all,
                          data.metro,
                          dt_metro_int,
                          dt_metro_type,
                          data.year_of_construction,
                          data.house_type,
                          data.cnt_entrance,
                          data.cnt_flats,
                          data.name_of_district,
                          district_population,
                          avg_age,
                          phone_first,
                          phone_second,
                          data.time_of_posting.apply(time_posting),           
                          [dt for i in range(data.shape[0])]  
                         ),
                 columns = ['id',
                            'cnt_rooms',
                            'total_area',
                            'kitchen_area',
                            'living_area',
                            'floor_cur',
                            'floor_all',
                            'price_all',
                            'price_m2',
                            'avg_price_m2_in_house',
                            'avg_price_m2_in_district',
                            'avg_rental_rate',
                            'popularity_today',
                            'popularity_all',
                            'metro',
                            'metro_time',
                            'metro_time_type',
                            'year_of_construction',
                            'house_type',
                            'cnt_entrance',
                            'cnt_flats',
                            'name_of_district',
                            'district_population',
                            'avg_age_of_constructions',
                            'phone_first',
                            'phone_second',
                            'dt_post',
                            'dt_report'
                           ]
                )

# %%
data_clean
# Out:
#             id  cnt_rooms  total_area  kitchen_area  living_area  floor_cur  \
# 0    149386843          3          58           8.0         42.0          8
# 1     28139920          4          10          10.0         64.0          6
# 2    149346311          3          65           7.0         45.0          9
# 3     40058747          3          63           7.0         47.0          1
# 4    146945483          5          10          17.2         61.0          1
# 5     22527282          2          59          10.0         36.0         21
# 6    145522442          2          56          10.0         32.0          2
# 7    147924231          3          76          11.0         51.0          2
# 8    145240694          1          32           7.0         18.1          1
# 9    149431421          3          62           9.0         40.0          4
# 10   149245791          1          40           8.0         19.0          2
# 11    49459041          2          44           6.0         28.0          8
# 12    49081631          3          74          10.8         47.0         10
# 13   149389438          1          39           9.0         20.0          5
# 14    35796036          1          40           9.0         21.0          3
# 15   148871642          1          41           9.5         20.6          9
# 16   148468969          1          40           8.0         20.0          6
# 17    30776248          4          63           6.0         46.0          5
# 18   149413560          2          52           9.0         31.0         12
# 19    50763983          2          45           6.0         28.0          8
# 20   149533940          1          39           8.5         21.0          6
# 21    49167439          3          74          11.0         48.0          4
# 22    23353626          1          33           6.1         19.0          5
# 23   149513315          3          52           6.0         37.0          2
# 24    34172398          2          54           9.6         30.2         14
# 25   148566136          1          38          10.0         17.0         14
# 26    46960587          1          38           9.0         20.0          1
# 27    32968210          4          10          10.0         62.8         10
# 28   147490831          1          39           8.4         19.0          2
# 29   141917445          1          33           6.0         18.7          9
# 358         12    8100000   126562.0                154391     ...
# 359          9    7500000   125000.0                151113     ...
# 360         17    5200000   136842.0                158173     ...
# 361         17   11500000   151316.0                153119     ...
# 362          9    5600000   169697.0                155519     ...
# 363          9    7500000   144231.0                157283     ...
# 364          9    8500000   193182.0                154774     ...
# 365         17    9000000   173077.0                155413     ...
# 366         22    5600000   140000.0                163521     ...
# 367         17   10500000   138158.0                150361     ...
# 368          9    7700000   163830.0                152843     ...
# 369         22    8000000   142857.0                150918     ...
# 370         12   10250000   165323.0                151901     ...
# 371          9    8100000   139655.0                153325     ...
# 372         16    7600000   149020.0                161661     ...
# 373         12    6100000   156410.0                152802     ...
# 374         16    7600000   149020.0                161661     ...
# 375         16    5700000   135714.0                151758     ...
# 376         16    7600000   149020.0                161661     ...
# 377         17    9400000   167857.0                165152     ...
# 378          9    7600000   126667.0                155828     ...
# 379         12    7200000   138462.0                153551     ...
# 380         16    8700000   150000.0                158173     ...
# 381          9    8400000   129231.0                154264     ...
#
#     house_type cnt_entrance  cnt_flats  name_of_district district_population  \
# 0    панельный          6.0      215.0         Зябликово              132348
# 1    панельный          2.0      174.0         Зябликово              132348
# 2    панельный         12.0      567.0         Зябликово              132348
# 3    панельный         12.0      567.0         Зябликово              132348
# 4    панельный          4.0      190.0         Зябликово              132348
# 5    панельный          3.0      261.0         Зябликово              132348
# 6    панельный          3.0      416.0         Зябликово              132348
# 7    панельный          3.0      203.0         Зябликово              132348
# 8    панельный          4.0      144.0         Зябликово              132348
# 9    панельный          4.0      190.0         Зябликово              132348
# 10   панельный          3.0      203.0         Зябликово              132348
# 11   панельный          6.0      202.0         Зябликово              132348
# 12   панельный          7.0      474.0         Зябликово              132348
# 13   панельный          4.0      223.0         Зябликово              132348
# 14   панельный          8.0      378.0         Зябликово              132348
# 15   панельный          9.0      470.0         Зябликово              132348
# 16   панельный          6.0      334.0         Зябликово              132348
# 17   панельный          6.0      210.0         Зябликово              132348
# 18   панельный          3.0      167.0         Зябликово              132348
# 19   панельный          8.0      287.0         Зябликово              132348
# 20   панельный          4.0      223.0         Зябликово              132348
# 21   панельный          3.0      416.0         Зябликово              132348
# 22   панельный          4.0      144.0         Зябликово              132348
# 23   панельный          6.0      215.0         Зябликово              132348
# 24   панельный          3.0      167.0         Зябликово              132348
# 25     блочный          1.0      283.0         Зябликово              132348
# 26   панельный          3.0      202.0         Зябликово              132348
# 27   панельный          2.0      174.0         Зябликово              132348
# 28   панельный          2.0       88.0         Зябликово              132348
# 29   панельный          6.0      215.0         Зябликово              132348
# ..         ...          ...        ...               ...                 ...
# 352  панельный          3.0      416.0         Зябликово              132348
# 353  панельный          3.0      167.0         Зябликово              132348
# 354       none          1.0      136.0         Зябликово              132348
# 355       none          1.0      136.0         Зябликово              132348
# 356  панельный          8.0      382.0         Зябликово              132348
# 357  панельный          4.0      191.0         Зябликово              132348
# 358  панельный          4.0      191.0         Зябликово              132348
# 359  панельный         10.0      359.0         Зябликово              132348
