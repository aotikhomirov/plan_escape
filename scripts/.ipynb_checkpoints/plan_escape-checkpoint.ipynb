# %%
import pandas as pd
import numpy as np
import re
import datetime

data = pd.read_excel('C:\Users\Valery\Desktop\plan_escape\data\search_060916.xlsx')
dt = datetime.date(2016, 9, 11)

def first_number(x):
    x = re.sub(' +', '', x)
    if x == 'NULL':
        return -1
    
    else:
        return int(re.findall('^\d+', x)[0])
   
    
def text_string(x):
    x = re.sub(' +', '', x)
    if x == 'NULL':
        return 'NULL'
    else:
        return re.findall('^\d+(\D+)', x)[0] 

def phone_num(x):
    phone_list = re.findall('\d.\d{3}.\d{3}.\d{2}.\d{2}',x)
    phone_list = [re.sub('\D','',x) for x in phone_list]
    if len(phone_list) == 0:
        return [-1,-1]
    else:
        phone_list = [int(x) for x in phone_list]
    if len(phone_list) == 1:
        phone_list.append(-1)
    return phone_list

def time_posting(x):
    hour = int(re.findall(', (\d+):\d+',x)[0])
    minute = int(re.findall(', \d+:(\d+)',x)[0])
    s = re.split(',', x)[0]
    if s == u'вчера':
        dt_tmp = dt + datetime.timedelta(-1)
        day = dt_tmp.day
        month = dt_tmp.month
    elif s == u'сегодня': 
        day = dt.day
        month = dt.month
    else:
        s = re.sub(u'янв', '01', s.lower())
        s = re.sub(u'фев', '02', s.lower())
        s = re.sub(u'мар', '03', s.lower())
        s = re.sub(u'апр', '04', s.lower())
        s = re.sub(u'май', '05', s.lower())
        s = re.sub(u'июн', '06', s.lower())
        s = re.sub(u'июл', '07', s.lower())
        s = re.sub(u'авг', '08', s.lower())
        s = re.sub(u'сен', '09', s.lower())
        s = re.sub(u'окт', '10', s.lower())
        s = re.sub(u'ноя', '11', s.lower())
        s = re.sub(u'дек', '12', s.lower())
        day = int(re.findall('(\d+) \d+', s)[0])
        month = int(re.findall('\d+ (\d+)', s)[0])
    year = datetime.date.today().year
    return datetime.datetime(year,month,day,hour,minute)

#cnt_rooms = data.cnt_rooms.apply(lambda x: int(re.findall('^\d',x)[0]))
#2*x if x < 10 else raise_(Exception('foobar'))
cnt_rooms = data.cnt_rooms.apply(lambda x: -1 if len(re.findall('^\d',x))==0
                                                 else int(re.findall('^\d',x)[0]))
flat_ids = data.url.apply(lambda x: -1 if len(re.findall('/(\d+)/',x))==0
                                        else int(re.findall('/(\d+)/',x)[0]))
#data.dt_metro.fillna('NULL',inplace=True)
#dt_metro_int = data.dt_metro.apply(first_number)
dt_metro_int = data.dt_metro.apply(lambda x: -1 if len(re.findall('^\d+', re.sub(' +', '', x)))==0
                                                else int(re.findall('^\d+', re.sub(' +', '', x))[0]))
#dt_metro_type =  data.dt_metro.apply(text_string)
dt_metro_type =  data.dt_metro.apply(lambda x: "NULL" if len(re.findall('^\d+(\D+)', x))==0
                                                         else re.findall('^\d+(\D+)', x)[0])
#popularity_all = data.popularity.apply(lambda x: int(re.findall(u'всего (\d+)',x)[0]))
data.popularity.fillna("NULL",inplace=True)
popularity_all = data.popularity.apply(lambda x: -1 if len(re.findall(u'всего (\d+)',x))==0 
                                                       else int(re.findall(u'всего (\d+)',x)[0]))
#popularity_today = data.popularity.apply(lambda x: int(re.findall(u'сегодня (\d+)',x)[0]))
popularity_today = data.popularity.apply(lambda x: -1 if len(re.findall(u'сегодня (\d+)',x))==0
                                                         else int(re.findall(u'сегодня (\d+)',x)[0]))
#floor_cur = data.floor.apply(lambda x: int(re.split('/',x)[0]))
#floor_all = data.floor.apply(lambda x: int(re.split('/',x)[1]))
floor_cur = data.floor.apply(lambda x: -1 if len(re.findall('/',x))==0
                                                         else int(re.split('/',x)[0]))
floor_all = data.floor.apply(lambda x: -1 if len(re.findall('/',x))==0
                                                         else int(re.split('/',x)[1]))


#living_area = data.living_area.apply(lambda x: float(re.sub(u'\u2013','-1',re.sub(',','.',re.sub(u'м2','',x)))))
#kitchen_area = data.kitchen_area.apply(lambda x: float(re.sub(u'\u2013','-1',re.sub(',','.',re.sub(u'м2','',x)))))
living_area = data.living_area.apply(lambda x: -1 if not isinstance(re.sub(u'\u2013','-1',re.sub(',','.',re.sub(u'м2','',f))), float)
                                                         else float(re.sub(u'\u2013','-1',re.sub(',','.',re.sub(u'м2','',x)))))
kitchen_area = data.kitchen_area.apply(lambda x: -1 if not isinstance(re.sub(u'\u2013','-1',re.sub(',','.',re.sub(u'м2','',f))), float)
                                                         else float(re.sub(u'\u2013','-1',re.sub(',','.',re.sub(u'м2','',x)))))

for f in ['avg_price_m2_in_house',
          'avg_rental_rate',
          'district_population',
          'avg_age',
          'avg_price_m2_in_district']:
    data[f].fillna('0',inplace=True)
avg_price_m2_in_house = data.avg_price_m2_in_house.apply(lambda x: re.sub('\D','',x))
avg_rental_rate = data.avg_rental_rate.apply(lambda x: re.sub('\D','',x))
district_population = data.district_population.apply(lambda x: re.sub('\D','',x))
avg_age = data.avg_age.apply(lambda x: re.sub('\D','',x))
avg_price_m2_in_district = data.avg_price_m2_in_district.apply(lambda x: re.sub('\D','',x))
phone_first = [x[0] for x in data.message.apply(phone_num)]
phone_second = [x[1] for x in data.message.apply(phone_num)]

data_clean = pd.DataFrame(data=zip(flat_ids,
                          cnt_rooms,
                          data.total_area,
                          kitchen_area,
                          living_area,
                          floor_cur,
                          floor_all,
                          data.price_all,
                          np.round((data.price_all/data.total_area).values),
                          avg_price_m2_in_house,
                          avg_price_m2_in_district,
                          avg_rental_rate,
                          popularity_today,
                          popularity_all,
                          data.metro,
                          dt_metro_int,
                          dt_metro_type,
                          data.year_of_construction,
                          data.house_type,
                          data.cnt_entrance,
                          data.cnt_flats,
                          data.name_of_district,
                          district_population,
                          avg_age,
                          phone_first,
                          phone_second,
                          data.time_of_posting.apply(time_posting),           
                          [dt for i in range(data.shape[0])]  
                         ),
                 columns = ['id',
                            'cnt_rooms',
                            'total_area',
                            'kitchen_area',
                            'living_area',
                            'floor_cur',
                            'floor_all',
                            'price_all',
                            'price_m2',
                            'avg_price_m2_in_house',
                            'avg_price_m2_in_district',
                            'avg_rental_rate',
                            'popularity_today',
                            'popularity_all',
                            'metro',
                            'metro_time',
                            'metro_time_type',
                            'year_of_construction',
                            'house_type',
                            'cnt_entrance',
                            'cnt_flats',
                            'name_of_district',
                            'district_population',
                            'avg_age_of_constructions',
                            'phone_first',
                            'phone_second',
                            'dt_post',
                            'dt_report'
                           ]
                )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-c6f3d53214a4> in <module>()
#     138                           phone_first,
#     139                           phone_second,
# --> 140                           data.time_of_posting.apply(time_posting),
#     141                           [dt for i in range(data.shape[0])]
#     142                          ),
#
# C:\Users\Valery\Anaconda2\lib\site-packages\pandas\core\series.pyc in apply(self, func, convert_dtype, args, **kwds)
#    2235             values = lib.map_infer(values, boxer)
#    2236
# -> 2237         mapped = lib.map_infer(values, f, convert=convert_dtype)
#    2238         if len(mapped) and isinstance(mapped[0], Series):
#    2239             from pandas.core.frame import DataFrame
#
# pandas\src\inference.pyx in pandas.lib.map_infer (pandas\lib.c:63043)()
#
# <ipython-input-52-c6f3d53214a4> in time_posting(x)
#      35
#      36 def time_posting(x):
# ---> 37     hour = int(re.findall(', (\d+):\d+',x)[0])
#      38     minute = int(re.findall(', \d+:(\d+)',x)[0])
#      39     s = re.split(',', x)[0]
#
# C:\Users\Valery\Anaconda2\lib\re.pyc in findall(pattern, string, flags)
#     179
#     180     Empty matches are included in the result."""
# --> 181     return _compile(pattern, flags).findall(string)
#     182
#     183 if sys.hexversion >= 0x02020000:
#
# TypeError: expected string or buffer

# %%
for f in data.living_area:
    print f
    print not isinstance(re.sub(u'\u2013','-1',re.sub(',','.',re.sub(u'м2','',f))), float)
# Out:
# 19 м2
# True
# 22 м2
# True
# 15,5 м2
# True
# 29 м2
# True
# 25,2 м2
# True
# 28 м2
# True
# 23 м2
# True
# 15 м2
# True
# 27 м2
# True
# 17,7 м2
# True
# 18 м2
# True
# 18 м2
# True
# 17 м2
# True
# 18 м2
# True
# 19 м2
# True
# 23 м2
# True
# 20 м2
# True
# –
# True
# 17 м2
# True
# 21 м2
# True
# 16 м2
# True
# 18 м2
# True
# 16 м2
# True
# 15,4 м2
# True
# 19 м2
# True
# 22,4 м2
# True
# 19 м2
# True
# 32 м2
# True
# 19,2 м2
# True
# 16 м2
# True
# 20 м2
# True
# 28 м2
# True
# 16,2 м2
# True
# 16 м2
# True
# 23 м2
# True
# 40 м2
# True
# 16 м2
# True
# 30,3 м2
# True
# 20 м2
# True
# 22 м2
# True
# 19 м2
# True
# 19 м2
# True
# 12,9 м2
# True
# 20 м2
# True
# 20 м2
# True
# 20 м2
# True
# 23 м2
# True
# 29 м2
# True
# 20 м2
# True
# 44 м2
# True
# 18 м2
# True
# 29 м2
# True
# 18 м2
# True
# 21 м2
# True
# 16,5+8,2-11,3 м2
# True
# 18 м2
# True
# 19 м2
# True
# –
# True
# 28 м2
# True
# 15 м2
# True
# 20 м2
# True
# 31 м2
# True
# 28 м2
# True
# 13,9 м2
# True
# 15 м2
# True
# 20 м2
# True
# 15 м2
# True
# 20 м2
# True
# 24 м2
# True
# 29,5 м2
# True
# 16 м2
# True
# 11,5 м2
# True
# 30 м2
# True
# 19 м2
# True
# 20 м2
# True
# 16,0 м2
# True
# 20 м2
# True
# 28,2 м2
# True
# –
# True
# 19 м2
# True
# 20 м2
# True
# 30,9 м2
# True
# 24,5 м2
# True
# 22,5 м2
# True
# 29,2 м2
# True
# 27 м2
# True
# 14 м2
# True
# 34,5 м2
# True
# 11,3 м2
# True
# 14,8 м2
# True
# 14,5 м2
# True
# 20 м2
# True
# 30 м2
# True
# 15 м2
# True
# –
# True
# 23 м2
# True
# 20 м2
# True
# 30,3 м2
# True
# 16,1 м2
# True
# 19,1 м2
# True
# –
# True
# 20 м2
# True
# 14,5 м2
# True
# 20 м2
# True
# 11,5 м2
# True
# 11,5 м2
# True
# –
# True
# 23,3 м2
# True
# 31 м2
# True
# 43,2 м2
# True
# 16,1 м2
# True
# 19,5 м2
# True
# 15 м2
# True
# 32 м2
# True
# 27 м2
# True
# 15 м2
# True
# 19,1 м2
# True
# 14,4 м2
# True
# 26 м2
# True
# 15,4 м2
# True
# 15,4 м2
# True
# 16 м2
# True
# 32 м2
# True
# 31,8 м2
# True
# 39 м2
# True
# 12,6 м2
# True
# 18 м2
# True
# 29 м2
# True
# 18 м2
# True
# 18 м2
# True
# 19,5 м2
# True
# 18 м2
# True
# 19 м2
# True
# 15,5 м2
# True
# 19 м2
# True
# 20,1 м2
# True
# 23 м2
# True
# 19,5 м2
# True
# –
# True
# 19,2 м2
# True
# 31 м2
# True
# 12,9 м2
# True
# –
# True
# 17 м2
# True
# 11,5 м2
# True
# 16,6 м2
# True
# 18 м2
# True
# 15,7 м2
# True
# 18 м2
# True
# 21 м2
# True
# 31,8 м2
# True
# 20 м2
# True
# 25 м2
# True
# 23 м2
# True
# 25 м2
# True
# 29 м2
# True
# 11,3 м2
# True
# 12,2 м2
# True
# 19 м2
# True
# 18 м2
# True
# 40,6 м2
# True
# 20 м2
# True
# 11,3 м2
# True
# 17,8 м2
# True
# 26 м2
# True
# 16,5 м2
# True
# 29 м2
# True
# 19,7 м2
# True
# 30 м2
# True
# 15 м2
# True
# 12,7 м2
# True
# 31,8 м2
# True
# 18,7 м2
# True
# 34 м2
# True
# 29 м2
# True
# 19 м2
# True
# 30 м2
# True
# 39 м2
# True
# 15 м2
# True
# 34 м2
# True
# 19,6 м2
# True
# 19 м2
# True
# 14,2 м2
# True
# 30 м2
# True
# 19 м2
# True
# 21,3 м2
# True
# 16,5 м2
# True
# 29 м2
# True
# 14 м2
# True
# 21 м2
# True
# 12 м2
# True
# 31 м2
# True
# 20 м2
# True
# 14 м2
# True
# 30,4 м2
# True
# 32 м2
# True
# 21 м2
# True
# 20 м2
# True
# 28 м2
# True
# 32 м2
# True
# 16,2 м2
# True
# 11,5 м2
# True
# 16,8 м2
# True
# 20,3 м2
# True
# 19,1 м2
# True
# 18 м2
# True
# 15,4 м2
# True
# 16,5 м2
# True
# 48 м2
# True
# 25 м2
# True
# 19 м2
# True
# 20 м2
# True
# 18 м2
# True
# 19 м2
# True
# 51 м2
# True
# 18 м2
# True
# 14,7 м2
# True
# 18 м2
# True
# 22,5 м2
# True
# 18 м2
# True
# 31 м2
# True
# 13,3 м2
# True
# 11,3 м2
# True
# 22,6 м2
# True
# 19 м2
# True
# 34 м2
# True
# 11,3 м2
# True
# 30 м2
# True
# 32 м2
# True
# 19 м2
# True
# 13,9 м2
# True
# 19 м2
# True
# 19 м2
# True
# 32 м2
# True
# 25,5 м2
# True
# 25,1 м2
# True
# 11,3 м2
# True
# 20 м2
# True
# 28,8 м2
# True
# –
# True
# 17,6 м2
# True
# 19,1 м2
# True
# 21 м2
# True
# –
# True
# 18 м2
# True
# 18 м2
# True
# 11,5 м2
# True
# 27 м2
# True
# 18,6 м2
# True
# 11,2 м2
# True
# 18 м2
# True
# 15 м2
# True
# 14,5 м2
# True
# 16,5 м2
# True
# 36,7 м2
# True
# 19 м2
# True
# 19 м2
# True
# –
# True
# 10+20+10 м2
# True
# 12,6 м2
# True
# 20 м2
# True
# 20 м2
# True
# 12,2 м2
# True
# 31,8 м2
# True
# 30,3 м2
# True
# 20 м2
# True
# 19,3 м2
# True
# 18 м2
# True
# 11,5 м2
# True
# 19 м2
# True
# 23,3 м2
# True
# 17,2 м2
# True
# 19 м2
# True
# 20 м2
# True
# 16 м2
# True
# 17 м2
# True
# 21 м2
# True
# 19 м2
# True
# 19,3 м2
# True
# 30 м2
# True
# 18,6 м2
# True
# 11,3 м2
# True
# 20 м2
# True
# 17 м2
# True
# 20 м2
# True
# 19 м2
# True
# 13 м2
# True
# 19 м2
# True
# 17,3 м2
# True
# 21,3 м2
# True
# 27 м2
# True
# 21 м2
# True
# 27 м2
# True
# 19 м2
# True
# 17 м2
# True
# 31,7 м2
# True
# 30,2 м2
# True
# 29,5 м2
# True
# 17 м2
# True
# 32 м2
# True
# 21,4 м2
# True
# 18 м2
# True
# 30,7 м2
# True
# 12,3 м2
# True
# –
# True
# 37,9 м2
# True
# 32 м2
# True
# 21 м2
# True
# 27 м2
# True
# 22,1 м2
# True
# 20,9 м2
# True
# 20 м2
# True
# 20,9 м2
# True
# 30,4 м2
# True
# 15,4 м2
# True
# 31,5 м2
# True
# 20 м2
# True
# 30,4 м2
# True
# 24 м2
# True
# 32 м2
# True
# 18 м2
# True
# 23,8 м2
# True
# 19 м2
# True
# 15,5 м2
# True
# 20,6 м2
# True
# 14,5 м2
# True
# 19 м2
# True
# 17 м2
# True
# 23 м2
# True
# 18 м2
# True
# 12 м2
# True
# 18 м2
# True
# 38,4 м2
# True
# 19 м2
# True
# 12,9 м2
# True
# 20 м2
# True
# 29 м2
# True
# 14,6 м2
# True
# 28,4 м2
# True
# 19 м2
# True
# 14,8 м2
# True
# 30 м2
# True
# 23 м2
# True
# 18,5 м2
# True
# 12,9 м2
# True
# 20 м2
# True
# 30 м2
# True
# 23,3 м2
# True
# 20 м2
# True
# 27 м2
# True
# 15 м2
# True
# 15 м2
# True
# 30 м2
# True
# 18,5 м2
# True
# 29 м2
# True
# 19 м2
# True
# 22,6 м2
# True
# 26 м2
# True
# –
# True
# 28,2 м2
# True
# 23 м2
# True
# 18 м2
# True
# 15 м2
# True
# 20 м2
# True
# 15,6 м2
# True
# 19 м2
# True
# 28 м2
# True
# 20 м2
# True
# 29 м2
# True
# 18 м2
# True
# 29 м2
# True
# 20 м2
# True
# 32 м2
# True
# 20 м2
# True
# 13 м2
# True
# 19 м2
# True
# 27 м2
# True
# 28 м2
# True
# 27,2 м2
# True
# 18,7 м2
# True
# 19,8 м2
# True
# 27,9 м2
# True
# 20,3 м2
# True
# 20 м2
# True
# 19 м2
# True
# 25,2 м2
# True
# 18 м2
# True
# 20 м2
# True
# 20,1 м2
# True
# 22,6 м2
# True
# 19 м2
# True
# 21,5 м2
# True
# 32 м2
# True
# 29 м2
# True
# 26 м2
# True
# 19,3 м2
# True
# 32 м2
# True
# 14,3 м2
# True
# 19 м2
# True
# 25 м2
# True
# 14,4 м2
# True
# 29,6 м2
# True
# 15 м2
# True
# 16,2 м2
# True
# 18 м2
# True
# 14,5 м2
# True
# 21 м2
# True
# 15 м2
# True
# 22,8 м2
# True
# 15 м2
# True
# 19,1 м2
# True
# 16,5 м2
# True
# 27,5 м2
# True
# 21 м2
# True
# 20 м2
# True
# 30 м2
# True
# 30 м2
# True
# 14,9 м2
# True
# 20 м2
# True
# 27 м2
# True
# 27 м2
# True
# 44,2 м2
# True
# 20 м2
# True
# 21,8 м2
# True
# 26,9 м2
# True
# 21,2 м2
# True
# 24 м2
# True
# 15,5 м2
# True
# 20 м2
# True
# 27 м2
# True
# 32 м2
# True
# 18 м2
# True
# 28 м2
# True
# 18 м2
# True
# 31 м2
# True
# 19 м2
# True
# 18 м2
# True
# 19,4 м2
# True
# 25 м2
# True
# 17 м2
# True
# 19,1 м2
# True
# 19,1 м2
# True
# 10+20+9 м2
# True
# 14,7 м2
# True
# 26,9 м2
# True
# 39 м2
# True
# 11,3 м2
# True
# 15 м2
# True
# 19 м2
# True
# 14,1 м2
# True
# 18 м2
# True
# –
# True
# 19 м2
# True
# 19,7 м2
# True
# 19,2 м2
# True
# 15,1 м2
# True
# 28,1 м2
# True
# 41 м2
# True
# 22,6 м2
# True
# 18 м2
# True
# 12,6 м2
# True
# 43,7 м2
# True
# 28 м2
# True
# 19,7 м2
# True
# 19,5 м2
# True
# 29 м2
# True
# 29 м2
# True
# 19,1 м2
# True
# 19 м2
# True
# 23 м2
# True
# 31 м2
# True
# 30 м2
# True
# 15 м2
# True
# 32 м2
# True
# 18,9 м2
# True
# 40 м2
# True
# 11,5 м2
# True
# 30,3 м2
# True
# 32 м2
# True
# 18 м2
# True
# 20 м2
# True
# 24 м2
# True
# 19 м2
# True
# 24 м2
# True
# 21 м2
# True
# 21 м2
# True
# 19 м2
# True
# 21 м2
# True
# 12,3 м2
# True
# 20 м2
# True
# 29 м2
# True
# 20 м2
# True
# 29 м2
# True
# –
# True
# 18,5 м2
# True
# 36 м2
# True
# 30 м2
# True
# 20 м2
# True
# 20 м2
# True
# 19 м2
# True
# 30 м2
# True
# 20 м2
# True
# 32 м2
# True
# 28 м2
# True
# 22,5 м2
# True
# 27 м2
# True
# 22,6 м2
# True
# 14,5 м2
# True
# 43 м2
# True
# 20 м2
# True
# 36 м2
# True
# 28 м2
# True
# 15 м2
# True
# 20,1 м2
# True
# 19 м2
# True
# 24,5 м2
# True
# 19 м2
# True
# 19 м2
# True
# 20 м2
# True
# 18 м2
# True
# 12,3 м2
# True
# –
# True
# 13,9 м2
# True
# 20,3 м2
# True
# 20 м2
# True
# 26,2 м2
# True
# 32 м2
# True
# 28,5 м2
# True
# 16,5 м2
# True
# 20 м2
# True
# 30 м2
# True
# 19 м2
# True
# 30,5 м2
# True
# 12 м2
# True
# 17 м2
# True
# 25 м2
# True
# 19 м2
# True
# 26,5 м2
# True
# 20 м2
# True
# 24 м2
# True
# 28 м2
# True
# 36 м2
# True
# 18,4 м2
# True
# 46 м2
# True
# 14 м2
# True
# 19 м2
# True
# 18,5 м2
# True
# 11,3 м2
# True
# 20 м2
# True
# 27,7 м2
# True
# 31 м2
# True
# 28 м2
# True
# 22,5 м2
# True
# 15,6 м2
# True
# 18 м2
# True
# 20 м2
# True
# 20 м2
# True
# 28 м2
# True
# 43 м2
# True
# 18,9 м2
# True
# –
# True
# 21 м2
# True
# 22 м2
# True
# 20 м2
# True
# 19 м2
# True
# 15 м2
# True
# 14 м2
# True
# 16 м2
# True
# 28,5 м2
# True
# 36 м2
# True
# 25 м2
# True
# 22 м2
# True
# 19,2 м2
# True
# 34,1 м2
# True
# 14 м2
# True
# 21 м2
# True
# 40 м2
# True
# 18 м2
# True
# 11,3 м2
# True
# 20 м2
# True
# 14,5 м2
# True
# 19 м2
# True
# 21 м2
# True
# 18,9 м2
# True
# 19,1 м2
# True
